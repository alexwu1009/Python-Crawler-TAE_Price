# %%
import ssl
import requests
import xml.etree.ElementTree as ET
import pandas as pd
from bs4 import BeautifulSoup
ssl._create_default_https_context = ssl._create_unverified_context

# %%
def TAE_now_tea_price():
    url = 'https://donghetea.com/fanti/quotes.php?id=5'
    r = requests.get(url ,headers={'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'})
    html_str = r.text
    soup = BeautifulSoup(html_str, 'lxml')
    teas = soup.find_all('li', 'quotes_list')
    result = []
    for tea in teas:
        name = tea.find("span", "dh1").text.strip()
        price = tea.find("span", "dh2").text.strip()
        up = tea.find("span", "dh3").text.strip()
        down = tea.find("span", "dh4").text.strip()
        date = tea.find("span", "dh6").text.strip()
        evaluation = tea.find("span", "dh7").text.strip().replace('\n|', '')
        result.append((name, price, up, down, date, evaluation))
    now_tea_df = pd.DataFrame(result, columns=['產品名', '參考價', '升跌幅度', '升降百分比', '更新日期', '評分'])
    return now_tea_df
def TAE_New_tea_price():
    url = 'https://donghetea.com/fanti/quotes.php?id=6'
    r = requests.get(url ,headers={'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'})
    html_str = r.text
    soup = BeautifulSoup(html_str, 'lxml')
    teas = soup.find_all('li', 'quotes_list')
    result = []
    for tea in teas:
        name = tea.find("span", "dh1").text.strip()
        price = tea.find("span", "dh2").text.strip()
        up = tea.find("span", "dh3").text.strip()
        down = tea.find("span", "dh4").text.strip()
        date = tea.find("span", "dh6").text.strip()
        evaluation = tea.find("span", "dh7").text.strip().replace('\n|', '')
        result.append((name, price, up, down, date, evaluation))
    new_tea_df = pd.DataFrame(result, columns=['產品名', '參考價', '升跌幅度', '升降百分比', '更新日期', '評分'])
    return new_tea_df
def TAE_NewMiddle_tea_price():
    url = 'https://donghetea.com/fanti/quotes.php?id=7'
    r = requests.get(url ,headers={'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'})
    html_str = r.text
    soup = BeautifulSoup(html_str, 'lxml')
    teas = soup.find_all('li', 'quotes_list')
    result = []
    for tea in teas:
        name = tea.find("span", "dh1").text.strip()
        price = tea.find("span", "dh2").text.strip()
        up = tea.find("span", "dh3").text.strip()
        down = tea.find("span", "dh4").text.strip()
        date = tea.find("span", "dh6").text.strip()
        evaluation = tea.find("span", "dh7").text.strip().replace('\n|', '')
        result.append((name, price, up, down, date, evaluation))
    new_middle_df = pd.DataFrame(result, columns=['產品名', '參考價', '升跌幅度', '升降百分比', '更新日期', '評分'])
    return new_middle_df

# %%
now_tea_long = TAE_now_tea_price()
new_tea_long = TAE_New_tea_price()
new_middle_long = TAE_NewMiddle_tea_price()

# %%
now_tea_long
# Out:
#                產品名      參考價    升跌幅度     升降百分比        更新日期          評分
# 0    2101 力开天地(散提)   ￥58000  ↑￥1000   ↑  1.8%  2021-01-10   72分 42人評分
# 1                     ￥5800   ↑￥300   ↑  5.5%  2020-12-26    72分 7人評分
# 2         2001 老茶頭    ￥5250   ↓￥100   ↓  1.9%  2020-12-07    86分 4人評分
# 3                    ￥49000  ↓￥1000     ↓  2%  2021-01-02  85分 104人評分
# 4    2001 群峰之上(散提)  ￥12.85萬  ↓￥1500   ↓  1.2%  2021-01-07  71分 133人評分
# 5        2001 7742   ￥14200   ↑￥400   ↑  2.9%  2020-12-30   67分 13人評分
# 6        2001 7742   ￥16200   ↑￥900   ↑  5.9%  2020-12-30   80分 61人評分
# 7        2001 7742   ￥83000  ↑￥2000   ↑  2.5%  2020-12-29   55分 63人評分
# 8        2001 7692    ￥2600    ↓￥50   ↓  1.9%  2020-11-01    99分 9人評分
# 9     1901 高山韻象(生)   ￥97000  ↓￥3000     ↓  3%  2021-01-10  69分 170人評分
# 10         1901 古街    ￥6300   ↓￥500   ↓  7.4%  2020-12-20   67分 95人評分
# 11       1901 越陳越香    ￥4300   ↓￥300   ↓  6.5%  2020-12-04   86分 26人評分
# 12       1901 8542   ￥12000   ↑￥500   ↑  4.3%  2020-12-29  85分 124人評分
# 13       2001 招财进宝   ￥70000  ↓￥2500   ↓  3.4%  2020-12-04  40分 258人評分
# 14                   ￥54000  ↓￥1500   ↓  2.7%  2021-01-08  86分 415人評分
# 15       2001 7542   ￥81000  ↑￥3000   ↑  3.8%  2020-12-29  86分 171人評分
# 16       2001 7572   ￥10500  ↓￥1500  ↓  12.5%  2020-11-26   94分 72人評分
# 17    1901 高山韻象(熟)    ￥4000    ↑￥50   ↑  1.3%  2020-12-20   95分 18人評分
# 18    2001洞天福地(散提)   ￥39000  ↓￥1000   ↓  2.5%  2021-01-09  93分 169人評分
# 19        2001洞天福地   ￥22.2萬  ↓￥3000   ↓  1.3%  2021-01-10  87分 301人評分
# 20       1901 7592    ￥2450   ↑￥150   ↑  6.5%  2020-12-24   98分 49人評分
# 21  1901 老茶磚(生熟套裝)   ￥17000  ↓￥1000   ↓  5.6%  2020-12-04   85分 24人評分
# 22     1901 滄海(散片)    ￥8000   ↓￥800   ↓  9.1%  2020-12-03    78分 9人評分
# 23         1901 煙霞    ￥6500  ↓￥1500  ↓  18.8%  2020-12-04   87分 24人評分
# 24       1901 內家功夫   ￥27800   ↑￥800     ↑  3%  2020-12-30   91分 81人評分
# 25        1901 益原素    ￥7050    ↓￥50   ↓  0.7%  2020-11-01   98分 12人評分
# 26       1901 紫金貢餅    ￥6500  ↓￥1500  ↓  18.8%  2020-11-23   96分 67人評分
# 27         1901 滄海   ￥50000  ↓￥3000   ↓  5.7%  2020-12-03  84分 107人評分

# %%
new_tea_long
# Out:
#                   產品名     參考價     升跌幅度     升降百分比        更新日期          評分
# 0           1801 長安印象  ￥15000       ￥0        0%  2020-12-15     0分 0人評分
# 1           1801 盛世長安    ￥18萬       ￥0        0%  2020-12-15     8分 1人評分
# 2       1701 凰后歸來800克  ￥13.8萬   ↓￥2000   ↓  1.4%  2020-12-22    99分 4人評分
# 3            1801 汉宫月  ￥43000   ↓￥2000   ↓  4.4%  2020-11-01   53分 32人評分
# 4            801 0532   ￥7600    ↑￥100   ↑  1.3%  2020-03-18    89分 1人評分
# 5              201 佛緣  ￥37000    ↑￥200   ↑  0.5%  2020-10-26    78分 6人評分
# 6              901 雲鼎  ￥10000    ↑￥200     ↑  2%  2020-11-02    97分 2人評分
# 7           1801 巴黎妙韻  ￥26500    ↑￥500   ↑  1.9%  2020-12-29  94分 174人評分
# 8        2006年 州政府老班章   ￥310萬  ↓￥50000   ↓  1.6%  2020-12-07    36分 6人評分
# 9            1601 錦繡紅  ￥11000   ↓￥1000   ↓  8.3%  2020-12-22    94分 7人評分
# 10          1601 春秋套裝  ￥36000   ↓￥2000   ↓  5.3%  2020-12-22   94分 31人評分
# 11          1701 7592   ￥2400    ↑￥100   ↑  4.3%  2020-10-16    52分 2人評分
# 12           001 勐海印象  ￥18000   ↓￥1000   ↓  5.3%  2020-09-10   100分 1人評分
# 13       1601 芙蓉圓茶(熟)   ￥7000    ↓￥500   ↓  6.7%  2020-09-24    79分 3人評分
# 14       1601 芙蓉圓茶(生)  ￥10500   ↓￥1000   ↓  8.7%  2020-09-24    90分 4人評分
# 15             201 岩韻    ￥19萬  ↓￥15000   ↓  7.3%  2020-12-03  80分 237人評分
# 16          1602 8582   ￥5000    ↑￥200   ↑  4.2%  2020-12-08    91分 6人評分
# 17          1801 8592   ￥2500    ↑￥200   ↑  8.7%  2020-08-24    34分 1人評分
# 18           1801 V93   ￥2000    ↑￥100   ↑  5.3%  2020-11-02     0分 0人評分
# 19           801 7262   ￥7300    ↑￥100   ↑  1.4%  2020-07-12    74分 1人評分
# 20   2006年 南糯大樹圓茶(特制)    ￥19萬  ↓￥10000     ↓  5%  2020-12-07   84分 10人評分
# 21          1701 五子登科  ￥17500    ↓￥500   ↓  2.8%  2020-12-08   93分 58人評分
# 22  2008年 801 天上攸樂（生）    ￥17萬   ↑￥5000     ↑  3%  2020-06-21   48分 21人評分
# 23           702 7542  ￥11000    ↑￥500   ↑  4.8%  2020-11-19    83分 3人評分
# 24      901 69周年廠慶紀念餅  ￥40000   ↑￥1000   ↑  2.6%  2020-11-02    97分 7人評分
# 25           1801 老茶頭   ￥5200    ↑￥200     ↑  4%  2020-11-02   94分 18人評分
# 26          1801 7592   ￥2600    ↑￥350  ↑  15.6%  2020-11-02   100分 2人評分
# 27          1401 鉑金方磚   ￥6000    ↓￥800  ↓  11.8%  2020-11-14   95分 25人評分

# %%
new_middle_long
# Out:
#                      產品名     參考價     升跌幅度     升降百分比        更新日期         評分
# 0               508 7542  ￥89000   ↑￥1000   ↑  1.1%  2020-12-07    6分 1人評分
# 1     2004年 401 甲級熟沱250克    暫無報價       ￥0        0%  2020-11-03    0分 0人評分
# 2             401 喬木生態青餅   ￥370萬  ↓￥50000   ↓  1.3%  2020-12-07   54分 3人評分
# 3          2003年 七星班章四印餅  ￥1300萬    ↑￥50萬     ↑  4%  2021-01-08  54分 13人評分
# 4           912 中茶綠印7542    ￥32萬  ↑￥20000   ↑  6.7%  2020-12-15   67分 4人評分
# 5    501 v93十年磨壹劍250克(生)  ￥49000   ↑￥2000   ↑  4.3%  2020-12-07    0分 0人評分
# 6       2003年 301 易武7312  ￥24.5萬  ↑￥10000   ↑  4.3%  2020-08-22  100分 1人評分
# 7               501 7542  ￥38.5萬   ↑￥5000   ↑  1.3%  2020-11-28    0分 0人評分
# 8   2003年 003 咖啡大益357克普餅  ￥56500    ↑￥500   ↑  0.9%  2019-09-26   98分 1人評分
# 9              2001年甲級青沱  ￥13.5萬   ↓￥3000   ↓  2.2%  2020-10-13    0分 0人評分
# 10      2002年 普洱方茶生茶100克    ￥35萬  ↑￥10000   ↑  2.9%  2021-01-05  98分 17人評分
# 11        2003年 班章生態孔雀青沱   ￥680萬    ↑￥25萬   ↑  3.8%  2021-01-03   91分 1人評分
# 12       2000年 易武正山典藏壹首詩    ￥69萬  ↑￥40000   ↑  6.2%  2020-12-27   56分 3人評分
# 13         2000年 千禧紅高檔青餅    ￥55萬  ↑￥50000    ↑  10%  2020-09-22    0分 0人評分
# 14    2000年 雲南高級普洱散茶100克  ￥43000   ↑￥1000   ↑  2.4%  2020-01-13    0分 0人評分
# 15        2000年 中茶綠印7572    ￥14萬  ↑￥10000   ↑  7.7%  2019-06-17    0分 0人評分
# 16  2000年 無R紅大益7542 YSE版    ￥90萬  ↑￥80000   ↑  9.8%  2020-12-28    0分 0人評分
# 17      2001年 中茶紅印易武正山普餅    ￥12萬   ↑￥2000   ↑  1.7%  2020-02-28    0分 0人評分
# 18            2001年 班章貢餅   ￥140萬  ↑￥50000   ↑  3.7%  2020-12-28   97分 2人評分
# 19          2001年 宮廷普洱散茶    暫無報價       ￥0        0%  2019-12-27    0分 0人評分
# 20  2001年 雲南勐海高級普洱散茶200克  ￥42500   ↑￥1000   ↑  2.4%  2020-01-13    0分 0人評分
# 21    2001年 甲級雲南普洱散茶200克  ￥43500   ↑￥1000   ↑  2.4%  2020-01-13    0分 0人評分
# 22          2001年 甲級普洱熟沱  ￥45000   ↑￥1000   ↑  2.3%  2019-02-17    0分 0人評分
# 23    2001年 易武正山野生茶特級品熟沱  ￥19.6萬   ↑￥3000   ↑  1.6%  2020-01-13    0分 0人評分
# 24   2001年 103易武正山野生茶特級品    ￥68萬  ↑￥20000     ↑  3%  2020-07-12  100分 1人評分
# 25        2001年 中茶老樹圓茶普餅  ￥16.8萬  ↑￥20000  ↑  13.5%  2020-11-22    0分 0人評分
# 26     2001年 中茶綠印簡體雲7592  ￥79000   ↑￥1000   ↑  1.3%  2019-10-26    0分 0人評分
# 27         2001年 紅大益7262  ￥84000   ↑￥2000   ↑  2.4%  2020-11-02    0分 0人評分
